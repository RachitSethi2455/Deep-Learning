# %%
# Step 1: Import Libraries
import tensorflow as tf
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.applications.mobilenet_v2 import MobileNetV2
from tensorflow.keras.layers import Dense, Dropout, GlobalAveragePooling2D
from tensorflow.keras.models import Model
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint
from sklearn.metrics import classification_report, confusion_matrix, accuracy_score, precision_score, recall_score, f1_score
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import zipfile, os

# Step 2: Extract the Dataset
zip_path = "/content/archive (flower).zip"
extract_dir = "/content/flowers"
with zipfile.ZipFile(zip_path, 'r') as zip_ref:
    zip_ref.extractall(extract_dir)

# Step 3: Setup Paths for Training & Validation
base_dir = extract_dir
train_dir = os.path.join(base_dir, "train")
val_dir = os.path.join(base_dir, "valid")

# Step 4: Image Data Generators
img_size = (224, 224)
batch_size = 32

train_datagen = ImageDataGenerator(rescale=1./255,
                                   rotation_range=20,
                                   width_shift_range=0.2,
                                   height_shift_range=0.2,
                                   shear_range=0.2,
                                   zoom_range=0.2,
                                   horizontal_flip=True)

val_datagen = ImageDataGenerator(rescale=1./255)

train_ds = train_datagen.flow_from_directory(train_dir,
                                             target_size=img_size,
                                             batch_size=batch_size,
                                             class_mode='categorical',
                                             shuffle=True)

val_ds = val_datagen.flow_from_directory(val_dir,
                                         target_size=img_size,
                                         batch_size=batch_size,
                                         class_mode='categorical',
                                         shuffle=False)

# Step 5: Load Pretrained MobileNetV2
base_model = MobileNetV2(weights='imagenet', include_top=False, input_shape=(224, 224, 3))
base_model.trainable = False

# Step 6: Add Classification Head
x = base_model.output
x = GlobalAveragePooling2D()(x)
x = Dropout(0.3)(x)
predictions = Dense(train_ds.num_classes, activation='softmax')(x)
model = Model(inputs=base_model.input, outputs=predictions)

# Step 7: Compile Model
model.compile(optimizer=Adam(learning_rate=0.001),
              loss='categorical_crossentropy',
              metrics=['accuracy'])

# Step 8: Callbacks (Early Stopping & Best Model Checkpoint)
checkpoint_path = "/content/best_model.h5"
callbacks = [
    EarlyStopping(monitor='val_loss', patience=3, restore_best_weights=True),
    ModelCheckpoint(checkpoint_path, monitor='val_accuracy', save_best_only=True, mode='max', verbose=1)
]

# Step 9: Train (Feature Extraction)
history = model.fit(train_ds,
                    validation_data=val_ds,
                    epochs=10,
                    callbacks=callbacks)

# Step 10: Fine-Tuning
base_model.trainable = True
for layer in base_model.layers[:100]:
    layer.trainable = False

model.compile(optimizer=Adam(learning_rate=0.0001),
              loss='categorical_crossentropy',
              metrics=['accuracy'])

fine_tune_history = model.fit(train_ds,
                              validation_data=val_ds,
                              epochs=10,
                              callbacks=callbacks)

# Step 11: Plot Training & Validation Curves
def plot_training(history, fine_tune_history):
    acc = history.history['accuracy'] + fine_tune_history.history['accuracy']
    val_acc = history.history['val_accuracy'] + fine_tune_history.history['val_accuracy']
    loss = history.history['loss'] + fine_tune_history.history['loss']
    val_loss = history.history['val_loss'] + fine_tune_history.history['val_loss']

    epochs = range(1, len(acc) + 1)

    plt.figure(figsize=(12, 5))
    plt.subplot(1, 2, 1)
    plt.plot(epochs, acc, 'b-', label='Training Accuracy')
    plt.plot(epochs, val_acc, 'r-', label='Validation Accuracy')
    plt.xlabel('Epochs')
    plt.ylabel('Accuracy')
    plt.title('Training & Validation Accuracy')
    plt.legend()

    plt.subplot(1, 2, 2)
    plt.plot(epochs, loss, 'b-', label='Training Loss')
    plt.plot(epochs, val_loss, 'r-', label='Validation Loss')
    plt.xlabel('Epochs')
    plt.ylabel('Loss')
    plt.title('Training & Validation Loss')
    plt.legend()

    plt.show()

plot_training(history, fine_tune_history)

# Step 12: Model Evaluation
val_labels = val_ds.classes
class_names = list(val_ds.class_indices.keys())

pred_probs = model.predict(val_ds)
pred_labels = np.argmax(pred_probs, axis=1)

# Confusion Matrix
cm = confusion_matrix(val_labels, pred_labels)
plt.figure(figsize=(8, 6))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', xticklabels=class_names, yticklabels=class_names)
plt.xlabel('Predicted')
plt.ylabel('True')
plt.title('Confusion Matrix')
plt.show()

# Metrics
print("\nClassification Report:")
print(classification_report(val_labels, pred_labels, target_names=class_names))

accuracy = accuracy_score(val_labels, pred_labels)
precision = precision_score(val_labels, pred_labels, average='weighted')
recall = recall_score(val_labels, pred_labels, average='weighted')
f1 = f1_score(val_labels, pred_labels, average='weighted')
sensitivity_per_class = recall_score(val_labels, pred_labels, average=None)

print(f"\nOverall Accuracy: {accuracy:.4f}")
print(f"Precision (Weighted): {precision:.4f}")
print(f"Recall (Weighted): {recall:.4f}")
print(f"F1-score (Weighted): {f1:.4f}")
print(f"Sensitivity per class: {dict(zip(class_names, sensitivity_per_class))}")

# Step 13: Save Final Model
model.save("/content/flower_transfer_learning_model_final.h5")
print("Final model saved successfully!")
# Out:
# Found 1275 images belonging to 2 classes.
# Found 364 images belonging to 2 classes.
# /usr/local/lib/python3.12/dist-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# Epoch 1/10
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 453ms/step - accuracy: 0.6990 - loss: 0.5763
# Epoch 1: val_accuracy improved from -inf to 0.89286, saving model to /content/best_model.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 36s 684ms/step - accuracy: 0.7011 - loss: 0.5728 - val_accuracy: 0.8929 - val_loss: 0.2756
# Epoch 2/10
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 523ms/step - accuracy: 0.8898 - loss: 0.2573
# Epoch 2: val_accuracy improved from 0.89286 to 0.89560, saving model to /content/best_model.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 22s 561ms/step - accuracy: 0.8896 - loss: 0.2576 - val_accuracy: 0.8956 - val_loss: 0.2404
# Epoch 3/10
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 377ms/step - accuracy: 0.8957 - loss: 0.2610
# Epoch 3: val_accuracy improved from 0.89560 to 0.89835, saving model to /content/best_model.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 16s 408ms/step - accuracy: 0.8957 - loss: 0.2606 - val_accuracy: 0.8984 - val_loss: 0.2387
# Epoch 4/10
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 376ms/step - accuracy: 0.9007 - loss: 0.2260
# Epoch 4: val_accuracy did not improve from 0.89835
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 16s 411ms/step - accuracy: 0.9008 - loss: 0.2257 - val_accuracy: 0.8929 - val_loss: 0.2344
# Epoch 5/10
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 397ms/step - accuracy: 0.9309 - loss: 0.1690
# Epoch 5: val_accuracy improved from 0.89835 to 0.90659, saving model to /content/best_model.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 17s 429ms/step - accuracy: 0.9307 - loss: 0.1696 - val_accuracy: 0.9066 - val_loss: 0.2057
# Epoch 6/10
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 393ms/step - accuracy: 0.9215 - loss: 0.1772
# Epoch 6: val_accuracy did not improve from 0.90659
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 17s 417ms/step - accuracy: 0.9217 - loss: 0.1771 - val_accuracy: 0.9066 - val_loss: 0.1990
# Epoch 7/10
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 375ms/step - accuracy: 0.9231 - loss: 0.1795
# Epoch 7: val_accuracy improved from 0.90659 to 0.90934, saving model to /content/best_model.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 17s 419ms/step - accuracy: 0.9229 - loss: 0.1798 - val_accuracy: 0.9093 - val_loss: 0.1970
# Epoch 8/10
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 377ms/step - accuracy: 0.9198 - loss: 0.1725
# Epoch 8: val_accuracy improved from 0.90934 to 0.91209, saving model to /content/best_model.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 17s 419ms/step - accuracy: 0.9200 - loss: 0.1726 - val_accuracy: 0.9121 - val_loss: 0.1930
# Epoch 9/10
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 375ms/step - accuracy: 0.9449 - loss: 0.1531
# Epoch 9: val_accuracy improved from 0.91209 to 0.92033, saving model to /content/best_model.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 16s 407ms/step - accuracy: 0.9448 - loss: 0.1533 - val_accuracy: 0.9203 - val_loss: 0.1896
# Epoch 10/10
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 401ms/step - accuracy: 0.9299 - loss: 0.1580
# Epoch 10: val_accuracy did not improve from 0.92033
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 17s 423ms/step - accuracy: 0.9297 - loss: 0.1581 - val_accuracy: 0.9121 - val_loss: 0.1976
# Epoch 1/10
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 609ms/step - accuracy: 0.8985 - loss: 0.2346
# Epoch 1: val_accuracy did not improve from 0.92033
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 53s 838ms/step - accuracy: 0.8988 - loss: 0.2343 - val_accuracy: 0.9093 - val_loss: 0.3587
# Epoch 2/10
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 387ms/step - accuracy: 0.9537 - loss: 0.1092
# Epoch 2: val_accuracy did not improve from 0.92033
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 16s 411ms/step - accuracy: 0.9538 - loss: 0.1091 - val_accuracy: 0.8901 - val_loss: 0.4589
# Epoch 3/10
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 383ms/step - accuracy: 0.9654 - loss: 0.0966
# Epoch 3: val_accuracy did not improve from 0.92033
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 20s 405ms/step - accuracy: 0.9653 - loss: 0.0965 - val_accuracy: 0.8929 - val_loss: 0.5183
# Epoch 4/10
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 386ms/step - accuracy: 0.9805 - loss: 0.0562
# Epoch 4: val_accuracy improved from 0.92033 to 0.92582, saving model to /content/best_model.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 17s 434ms/step - accuracy: 0.9804 - loss: 0.0563 - val_accuracy: 0.9258 - val_loss: 0.2925
# Epoch 5/10
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 384ms/step - accuracy: 0.9748 - loss: 0.0642
# Epoch 5: val_accuracy improved from 0.92582 to 0.94780, saving model to /content/best_model.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 17s 419ms/step - accuracy: 0.9748 - loss: 0.0640 - val_accuracy: 0.9478 - val_loss: 0.2044
# Epoch 6/10
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 388ms/step - accuracy: 0.9885 - loss: 0.0392
# Epoch 6: val_accuracy improved from 0.94780 to 0.95604, saving model to /content/best_model.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 17s 419ms/step - accuracy: 0.9885 - loss: 0.0393 - val_accuracy: 0.9560 - val_loss: 0.2133
# Epoch 7/10
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 409ms/step - accuracy: 0.9834 - loss: 0.0315
# Epoch 7: val_accuracy did not improve from 0.95604
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 17s 430ms/step - accuracy: 0.9835 - loss: 0.0315 - val_accuracy: 0.9423 - val_loss: 0.2444
# Epoch 8/10
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 385ms/step - accuracy: 0.9927 - loss: 0.0195
# Epoch 8: val_accuracy did not improve from 0.95604
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 16s 409ms/step - accuracy: 0.9926 - loss: 0.0197 - val_accuracy: 0.9478 - val_loss: 0.2556
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 9s 434ms/step
# Classification Report:
#               precision    recall  f1-score   support
#
#        daisy       0.95      0.93      0.94       163
#    dandelion       0.95      0.96      0.95       201
#
#     accuracy                           0.95       364
#    macro avg       0.95      0.95      0.95       364
# weighted avg       0.95      0.95      0.95       364
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# Overall Accuracy: 0.9478
# Precision (Weighted): 0.9478
# Recall (Weighted): 0.9478
# F1-score (Weighted): 0.9478
# Sensitivity per class: {'daisy': np.float64(0.9325153374233128), 'dandelion': np.float64(0.9601990049751243)}
# Final model saved successfully!
